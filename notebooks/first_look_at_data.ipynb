# %%
import pandas as pd
import json
import re

# %%
df = pd.read_csv('../../data/BTW17_Suggestions/BTW_COMPLETE/suggestions_20210719.csv')
df.head()
# Out:
#    id     queryterm                 date   client lang  \
# 0   1  Jan van Aken  2017-02-13 17:13:45   chrome   de
# 1   2  Jan van Aken  2017-02-13 17:13:46   chrome   de
# 2   3  Jan van Aken  2017-02-13 17:13:46  firefox   de
# 3   4  Jan van Aken  2017-02-13 17:13:46  firefox   de
# 4   5  Jan van Aken  2017-02-13 17:13:46     serp   de
#
#                                                 url  \
# 0         http://clients1.google.de/complete/search
# 1  http://suggestqueries.google.com/complete/search
# 2         http://clients1.google.de/complete/search
# 3  http://suggestqueries.google.com/complete/search
# 4         http://clients1.google.de/complete/search
#
#                                             raw_data
# 0  ["Jan van Aken",["jan van aken privat","http:/...
# 1  ["Jan van Aken",["jan van aken privat","jan va...
# 2  ["Jan van Aken",["jan van aken","jan van aken ...
# 3  ["Jan van Aken",["jan van aken","jan van aken ...
# 4  ["Jan van Aken",["jan van aken","jan van aken ...

# %%
df.rename(columns={'date':'datetime'}, inplace=True)
df['date'] = df['datetime'].apply(lambda x: x.split(' ')[0])

# %%
df.describe(include='all').T
# Out:
#               count  unique  \
# id         928496.0     NaN
# queryterm    928496     805
# datetime     928496  496340
# client       928496       4
# lang         928496       2
# url          928496       2
# raw_data     928496   43063
# date         928496      78
#
#                                                          top    freq  \
# id                                                       NaN     NaN
# queryterm                                    Cemile Giousouf    3432
# datetime                                 2017-02-13 17:15:57       8
# client                                                 opera  232125
# lang                                                      de  916442
# url                http://clients1.google.de/complete/search  464252
# raw_data   ["Mathias Edwin Höschel",["mathias edwin hösch...     620
# date                                              2017-02-14   15720
#
#                     mean            std  min        25%       50%        75%  \
# id         464409.379134  268045.663412  1.0  232292.75  464416.5  696540.25
# queryterm            NaN            NaN  NaN        NaN       NaN        NaN
# datetime             NaN            NaN  NaN        NaN       NaN        NaN
# client               NaN            NaN  NaN        NaN       NaN        NaN
# lang                 NaN            NaN  NaN        NaN       NaN        NaN
# url                  NaN            NaN  NaN        NaN       NaN        NaN
# raw_data             NaN            NaN  NaN        NaN       NaN        NaN
# date                 NaN            NaN  NaN        NaN       NaN        NaN
#
#                 max
# id         928664.0
# queryterm       NaN
# datetime        NaN
# client          NaN
# lang            NaN
# url             NaN
# raw_data        NaN
# date            NaN

# %%
print('Der Slice beinhaltet Daten von {} bis {}.'.format(df['date'].min(), df['date'].max()))
# Out:
# Der Slice beinhaltet Daten von 2017-02-13 bis 2017-05-01.

# %% [markdown]
# Politische Themen 2017:
# https://www.deutschland.de/de/jahresrueckblick-deutschland-2017

# %%
df['g20'] = df['raw_data'].apply(lambda x: 1 if 'g20'.casefold() in str(x).casefold() else 0)
df['klima'] = df['raw_data'].apply(lambda x: 1 if 'klima'.casefold() in str(x).casefold() else 0)
df['saarland'] = df['raw_data'].apply(lambda x: 1 if 'saarland'.casefold() in str(x).casefold() else 0)

# %%
df[['date', 'g20', 'klima', 'saarland']].groupby('date').sum().plot(kind='line', figsize=(20,5),
                                                                    ylabel='Häufigkeit des Suchvorschlages',
                                                                    xlabel='Datum',
                                                                    title='Vorkommnisse der Suchvorschläge G20, Klima und Saarland in einem Slice des BTW17-Datensatzes');

# %% [markdown]
# Interessant: Die Landtagswahl im Saarland war am 26. März 2017. Zu diesem Zeitpunkt gehen dort auch die suggestion terms hoch.
